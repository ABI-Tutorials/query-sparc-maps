# %% [markdown]
# ## Demo for get species specific neuron populations and their evidences

# %%
from pprint import pprint
import requests
import pandas as pd

# %%
# Initialising the pg database endpoint
pg_endpoint = "https://mapcore-demo.org/devel/flatmap/v4/competency/"

# %% [markdown]
# ### Get List of Data Source
# Knowledge sources in the competency query system can include SCKAN versions (e.g., sckan-2024-09-21) as well as available flatmaps (e.g., 2b76d336-5c56-55e3-ab1e-795d6c63f9c1 for the male flatmap). While a dedicated query for listing all available sources is not yet implemented, it will be added in the future. For now, the available sources include:

# %%
MALE_FLATMAP = "2b76d336-5c56-55e3-ab1e-795d6c63f9c1"
FEMALE_FLATMAP = "91359a0f-9e32-5309-b365-145d9956817d"
RAT_FLATMAP = "fb6d0345-cb70-5c7e-893c-d744a6313c95"
SCKAN = "sckan-2024-09-21"

# %% [markdown]
# Different neuron populations and their evidences between species

# %%
# A function to get the query definition
def get_query_parameters(query_id):
    url = pg_endpoint + 'queries/' + str(query_id)
    response = requests.get(url)
    
    if response.status_code in (200, 201):
        return response.json()  # Return the query definition as a JSON object
    else:
        print(f"Error {response.status_code}: {response.json()}")
        return None

# A function to execute a query and return results from PostgreSQL
def execute(query):
    url = pg_endpoint + 'query'
    headers = {"Content-Type": "application/json"}
    
    response = requests.post(url, json=query, headers=headers)
    
    if response.status_code in (200, 201):
        return response.json().get('results', [])  # Safely get 'results' from response
    else:
        print(f"Error {response.status_code}: {response.json()}")
        return None

# %% [markdown]
# Returns neuron populations (paths) that are present in one species but not in the other. This query is useful for detecting species-specific neuron populations, such as those found in rats but absent in humans, or vice versa.

# %%
def get_species_specific_neuron_populations(source_id, taxon_id):
    query = {
        'query_id': '16', 
        'parameters': [
            
            {
                'column': 'taxon_id', 
                'value': taxon_id
            }, 
            {
                'column': 'source_id', 
                'value': source_id
            }
        ]
    }
    
    # Execute the query and print results
    query_results = execute(query)
    
    if query_results:
        return query_results
    else:
        print("Query execution failed or returned no results.")

# %% [markdown]
# Returns neuron populations (path_id) and their supporting evidence (evidence_id) that are uniquely associated with a specific species (taxon_id) at a given anatomical location (feature_id). This allows you to identify neuron populations that are specific to one species and absent in others, highlighting species-specific structural or evidential differences in neural circuits.

# %%
def get_species_specific_evidences(source_id, taxon_id, feature_id):
    query = {
        'query_id': '17', 
        'parameters': [
            
            {
                'column': 'taxon_id', 
                'value': taxon_id
            }, 
            {
                'column': 'feature_id', 
                'value': feature_id
            }, 
            {
                'column': 'source_id', 
                'value': source_id
            }
        ]
    }
    
    # Execute the query and print results
    query_results = execute(query)
    
    if query_results:
        return query_results
    else:
        print("Query execution failed or returned no results.")

# %% [markdown]
# You're comparing the neural circuits involved in bladder control between rats and humans. By specifying feature_id as "UBERON:0001255" (urinary bladder), the query identifies neuron populations that are present in rats but absent in humans (or vice versa), and links each to its supporting evidence. This helps reveal species-specific neuroanatomy that may impact translational research or therapeutic targeting.

# %%
get_species_specific_neuron_populations(SCKAN, 'NCBITaxon:10116') #rat
# Out:
# {'keys': ['source_id', 'taxon_id', 'path_id'],
#  'values': [['sckan-2024-09-21',
#    'NCBITaxon:10116',
#    'ilxtr:neuron-type-keast-1'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:neuron-type-keast-10'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:neuron-type-keast-11'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:neuron-type-keast-12'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:neuron-type-keast-13'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:neuron-type-keast-14'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:neuron-type-keast-15'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:neuron-type-keast-16'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:neuron-type-keast-17'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:neuron-type-keast-18'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:neuron-type-keast-19'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:neuron-type-keast-2'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:neuron-type-keast-20'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:neuron-type-keast-3'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:neuron-type-keast-4'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:neuron-type-keast-5'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:neuron-type-keast-6'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:neuron-type-keast-7'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:neuron-type-keast-8'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:neuron-type-keast-9'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/femrep/30'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/femrep/31'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/femrep/32'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/femrep/33'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/femrep/34'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/femrep/35'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/femrep/36'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/femrep/37'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/femrep/38'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/femrep/39'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/femrep/40'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/femrep/40-1'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/femrep/41'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/femrep/42'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/femrep/43'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/femrep/44'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/femrep/52'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/femrep/53'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/femrep/54'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/femrep/55'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/femrep/56'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/femrep/60'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/femrep/61'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/femrep/62'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/femrep/63'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/femrep/64'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/kidney/149'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/kidney/150'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/kidney/151'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/kidney/152'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/kidney/153'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/kidney/154'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/kidney/155'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/liver/105'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/liver/106'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/liver/107'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/liver/108'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/liver/109'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/liver/110'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/liver/111'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/liver/112'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/liver/113'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/liver/114'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/liver/115'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/mmset1/14'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/mmset4/2'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/mmset4/3a'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/mmset4/3b'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/mmset4/3c'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/mmset4/4a'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/mmset4/4b'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/mmset4/4c'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/mmset4/5'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/mmset4/6'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/mmset4/7'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/mmset4/9'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/prostate/11'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/prostate/12'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/prostate/13'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/prostate/14'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/semves/1'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/semves/2'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/semves/2a'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/semves/3'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/semves/4'],
#   ['sckan-2024-09-21', 'NCBITaxon:10116', 'ilxtr:sparc-nlp/semves/4a']]}

# %%
get_species_specific_neuron_populations(SCKAN, 'NCBITaxon:9606') #human
# Out:
# {'keys': ['source_id', 'taxon_id', 'path_id'],
#  'values': [['sckan-2024-09-21',
#    'NCBITaxon:9606',
#    'ilxtr:neuron-type-aacar-1'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:neuron-type-aacar-10a'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:neuron-type-aacar-10v'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:neuron-type-aacar-11'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:neuron-type-aacar-12'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:neuron-type-aacar-13'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:neuron-type-aacar-14'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:neuron-type-aacar-15'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:neuron-type-aacar-2i'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:neuron-type-aacar-2m'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:neuron-type-aacar-4'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:neuron-type-aacar-5'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:neuron-type-aacar-6'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:neuron-type-aacar-7a'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:neuron-type-aacar-7v'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:neuron-type-aacar-8a'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:neuron-type-aacar-8v'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:neuron-type-aacar-9a'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:neuron-type-aacar-9v'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/100'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/101'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/102'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/103'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/104'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/66'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/67'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/68'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/69'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/70'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/71'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/72'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/73'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/74'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/75'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/76'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/77'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/78'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/79'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/80'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/81'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/82'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/83'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/84'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/85'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/86'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/87'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/88'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/89'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/90'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/91'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/92'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/93'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/femrep/94'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/kidney/131'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/kidney/132'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/kidney/133'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/kidney/134'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/kidney/135'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/kidney/136'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/kidney/137'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/kidney/138'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/kidney/139'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/liver/116'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/liver/117'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/liver/118'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/liver/119'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/liver/120'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/liver/121'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/liver/122'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/liver/123'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/liver/124'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/liver/125'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/liver/126'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/liver/127'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/mmset1/1'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/mmset1/2'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/mmset4/1'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/mmset4/11'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/mmset4/12'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/mmset4/3'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/mmset4/3e'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/mmset4/8'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/mmset4/9'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/prostate/15'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/prostate/16'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/prostate/17'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/prostate/18'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/semves/5'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/semves/6'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/semves/7'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/semves/8'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/1'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/10'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/100'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/101'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/102'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/103'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/104'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/105'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/106'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/107'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/108'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/109'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/11'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/110'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/111'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/112'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/113'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/114'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/115'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/116'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/117'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/118'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/12'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/120'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/121'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/122'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/123'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/124'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/125'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/126'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/127'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/128'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/129'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/13'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/130'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/131'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/132'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/133'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/134'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/135'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/136'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/137'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/138'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/139'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/14'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/140'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/141'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/142'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/143'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/144'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/145'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/146'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/147'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/148'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/149'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/15'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/150'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/151'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/152'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/153'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/154'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/155'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/156'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/157'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/158'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/159'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/16'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/160'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/161'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/162'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/163'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/164'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/165'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/166'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/167'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/168'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/169'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/17'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/170'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/171'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/172'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/18'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/19'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/2'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/20'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/21'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/22'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/23'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/24'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/25'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/26'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/27'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/28'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/29'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/3'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/30'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/31'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/32'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/33'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/34'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/35'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/36'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/37'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/38'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/39'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/4'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/40'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/41'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/42'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/43'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/44'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/45'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/46'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/47'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/48'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/49'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/5'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/50'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/51'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/52'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/53'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/54'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/55'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/56'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/57'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/58'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/59'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/6'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/60'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/61'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/62'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/63'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/64'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/65'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/66'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/67'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/68'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/69'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/7'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/70'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/71'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/72'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/73'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/74'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/75'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/76'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/77'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/78'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/79'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/8'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/80'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/81'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/82'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/83'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/84'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/85'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/86'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/87'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/88'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/89'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/9'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/90'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/91'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/92'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/93'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/94'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/95'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/96'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/97'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/98'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/senmot/99'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/swglnd/156'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/swglnd/157'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/swglnd/158'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/swglnd/159'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/swglnd/160'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/swglnd/161'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/swglnd/162'],
#   ['sckan-2024-09-21', 'NCBITaxon:9606', 'ilxtr:sparc-nlp/swglnd/163']]}

# %%
get_species_specific_evidences(SCKAN, 'NCBITaxon:10116', 'UBERON:0002107') #liver
# Out:
# {'keys': ['source_id', 'taxon_id', 'path_id', 'evidence_id'], 'values': []}

# %%
get_species_specific_evidences(SCKAN, 'NCBITaxon:9606', 'UBERON:0002113') #liver
# Out:
# {'keys': ['source_id', 'taxon_id', 'path_id', 'evidence_id'],
#  'values': [['sckan-2024-09-21',
#    'NCBITaxon:9606',
#    'ilxtr:sparc-nlp/kidney/136',
#    'https://doi.org/10.1016/j.aanat.2015.11.004'],
#   ['sckan-2024-09-21',
#    'NCBITaxon:9606',
#    'ilxtr:sparc-nlp/kidney/139',
#    'https://doi.org/10.1016/j.aanat.2015.11.004'],
#   ['sckan-2024-09-21',
#    'NCBITaxon:9606',
#    'ilxtr:sparc-nlp/kidney/136',
#    'https://uilx.org/tgbugs/u/r/isbn-13/978-0323680424'],
#   ['sckan-2024-09-21',
#    'NCBITaxon:9606',
#    'ilxtr:sparc-nlp/kidney/139',
#    'https://uilx.org/tgbugs/u/r/isbn-13/978-0323680424']]}
